# %% [markdown]
# <a href="https://colab.research.google.com/github/NandikollaSatyaSuryakiran/FMML_LABS-AND-ASSIGNMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 07:48:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  61.7MB/s    in 1.1s
#
# 2024-04-01 07:48:44 (61.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 40359  cs/0605037v1  Clickthrough data is a particularly inexpensiv...    cs
# 11412  1601.02068v6  We derive computationally tractable methods to...  stat
# 2391    1303.0691v3  This paper deals with chain graphs under the A...  stat
# 21796  1604.01075v1  Many retailers today employ inventory manageme...  stat
# 12113  1708.07242v1  We present a new method of generating mixture ...  stat
# ...             ...                                                ...   ...
# 261    1611.06188v2  Recurrent neural networks (RNNs) have been use...  stat
# 39288  1508.02959v1  We present a system for the classification of ...    cs
# 15487  1507.01529v1  We consider a large number of text data sets. ...    cs
# 40770   1305.4757v1  A clustering is an implicit assignment of labe...    cs
# 22296  1512.03300v1  Topic models are popular for modeling discrete...  stat
#
#                                                    title  year  \
# 40359  Minimally Invasive Randomization for Collectin...  2006
# 11412  On Computationally Tractable Selection of Expe...  2016
# 2391   Learning AMP Chain Graphs and some Marginal Mo...  2013
# 21796  A Dynamic Bayesian Network Model for Inventory...  2016
# 12113   GALILEO: A Generalized Low-Entropy Mixture Model  2017
# ...                                                  ...   ...
# 261    Variable Computation in Recurrent Neural Networks  2016
# 39288     Mountain Peak Detection in Online Social Media  2015
# 15487  Correspondence Factor Analysis of Big Data Set...  2015
# 40770  Power to the Points: Validating Data Membershi...  2013
# 22296  Inference in topic models: sparsity and trade-off  2015
#
#                                                 keywords
# 40359  [clickthrough, particularly, inexpensive, plen...
# 11412  [computationally, tractable, experiment, regre...
# 2391   [andersson, interpretation, particular, constr...
# 21796  [retailers, inventory, management, assumption,...
# 12113  [generating, categorical, attributes, categori...
# ...                                                  ...
# 261    [recurrent, extensively, increasing, sequentia...
# 39288  [classification, panoramas, generated, photogr...
# 15487  [distribution, distributional, properties, inv...
# 40770  [clustering, assignment, proximity, downstream...
# 22296  [efficient, structuressemantics, posterior, in...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 40359    [clickthrough, particularly, inexpensive, plen...
# 11412    [computationally, tractable, experiment, regre...
# 2391     [andersson, interpretation, particular, constr...
# 21796    [retailers, inventory, management, assumption,...
# 12113    [generating, categorical, attributes, categori...
#                                ...
# 35302    [illustrates, chronological, backtracking, int...
# 16937    [discriminative, approaches, structure, predic...
# 13690    [propagation, algorithm, metaheuristics, inspi...
# 2620     [visualizations, interpretable, preferences, s...
# 26675    [techniques, precision, classification, detect...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8787 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e520ff6-078c-45f0-859b-d61020682ef2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e520ff6-078c-45f0-859b-d61020682ef2")) {                    Plotly.newPlot(                        "9e520ff6-078c-45f0-859b-d61020682ef2",                        [{"x":["minimally","particularly","assumptions","improving","personalizing","irrespective","experiments","documents","preferences","sufficient","judgments","reasonable","introduce","inexpensive","plentiful","probability","presentation","interactive","unaffected","collecting","presented","guaranteed","randomization","relevance","guarantees","intractable","computationally","regression","continuous","tractable","generalized","effectiveness","processing","synthetic","procedures","algorithms","optimization","measurement","approximation","constrained","relaxation","functions","established","otherwise","technique","combinatorial","selection","experiment","numerical","composition","distinguished","algorithm","characterize","constraint","dependencies","concentration","covariance","efficient","development","distribution","scoresearch","equivalence","conjecture","equivalent","transitivity","extension","particular","compromises","undirected","graphical","satisfies","interpretation","criterion","andersson","properties","marginalizing","faithfulness","unfortunately","varieties","quantities","nonlinear","situations","inventory","interaction","marketing","decreases","parameters","management","unobserved","motivated","variables","estimation","distributions","dimensional","discrepancies","expectation","assumption","consequence","maximization","annealing","components","consistently","promising","demonstrate","categorical","benchmarks","attributes","clustering","generating","representation","parameter","typically","probabilistic","structure","semantics","accompanying","conditions","inference","respected","attractive","completeness","therefore","techniques","describes","perceptron","piecewise","perceptrons","multilayer","performance","similarity","interpolation","annotation","supervised","empirical","weighting","dependency","influence","attachment","combination","sentences","adposition","significantly","comparing","subsequently","principal","correlated","multiplication","analytical","simultaneously","coherence","structured","normalized","different","remarkably","iterative","structures","unstructured","resemblance","recovered","component","challenging","automatic","convolutional","traditionally","microscope","incorporating","histology","requirement","pathologists","classification","metastases","framework","misdiagnosis","significant","predictions","computing","metastatic","diagnostic","indicators","surpassed","strategies","resolutions","prefetching","effectively","existence","detection","extensive","diagnosis","computerized","benchmark","expanding","metastasis","localization","asynchronous","leveraging","challenge","reconstructing","alleviates","classical","sensitivity"],"y":[5,77,61,109,2,1,628,67,35,75,11,30,345,6,3,145,10,39,2,14,176,32,7,34,61,18,88,124,114,37,73,225,285,140,34,617,327,29,133,64,20,198,67,16,233,35,154,72,82,25,4,854,50,100,47,9,15,412,147,217,0,14,14,56,4,81,283,1,10,52,12,65,51,0,219,2,0,36,4,9,57,46,7,72,6,10,249,42,5,73,138,209,113,178,3,31,67,20,30,8,110,45,110,576,6,78,58,157,103,374,140,103,169,348,92,4,152,198,2,30,16,134,397,82,22,13,7,21,876,144,18,47,205,158,20,48,55,4,123,62,2,247,78,34,38,22,6,22,87,15,90,26,754,12,90,114,17,5,14,105,285,192,387,17,3,59,4,36,4,502,3,555,2,225,81,130,2,19,11,4,109,14,2,116,32,342,170,39,4,219,6,1,53,14,46,160,16,7,109,32],"type":"bar"},{"x":["minimally","particularly","assumptions","improving","personalizing","irrespective","exper ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>4DFAB</span> <span style=''>A</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>4D</span> <span style=''>Facial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expression</span> <span style=''>Database</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.846153846153846);'>Biometric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <br/><br/><span style=''>The</span> <span style=''>progress</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3877551020408164);'>currently</span> <span style=''>witnessing</span> <span style=''>in</span> <span style=''>many</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.5546558704453441);'>automatic</span> <span style=''>face</span> <span style=''>analysis</span> <span style=''>would</span> <span style=''>not</span> <span style=''>be</span> <span style=''>made</span> <span style=''>possible</span> <span style=''>without</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>tremendous</span> <span style=''>efforts</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>collecting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>annotating</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.6338028169014085);'>databases</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>4DFAB</span> <span style=''>a</span> <span style=''>new</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>database</span> <span style=''>of</span> <span style=''>dynamic</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.5971223021582734);'>resolution</span> <span style=''>3D</span> <span style=''>faces</span> <span style=''>(over</span> <span style=''>1800000</span> <span style=''>3D</span> <span style=''>meshes)</span> <span style=''>4DFAB</span> <span style=''>contains</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recordings</span> <span style=''>of</span> <span style=''>180</span> <span style=''>subjects</span> <span style=''>captured</span> <span style=''>in</span> <span style=''>four</span> <span style='background-color:rgba(0, 255, 0, 0.32629727352682486);'>different</span> <span style=''>sessions</span> <span style=''>spanning</span> <span style=''>over</span> <span style=''>a</span> <span style=''>five</span> <span style=''>year</span> <span style=''>period</span> <span style=''>It</span> <span style=''>contains</span> <span style=''>4D</span> <span style=''>videos</span> <span style=''>of</span> <span style=''>subjects</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>displaying</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>spontaneous</span> <span style=''>and</span> <span style=''>posed</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>behaviours</span> <span style=''>The</span> <span style=''>database</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style=''>both</span> <span style=''>face</span> <span style=''>and</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expression</span> <span style='background-color:rgba(0, 255, 0, 0.675);'>recognition</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>behavioural</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Spatial</span> <span style=''>Modeling</span> <span style=''>of</span> <span style=''>Oil</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style=''>Areas</span> <span style=''>Using</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>and</span> <span style=''>ANFIS</span> <span style=''>in</span> <span style=''>GIS</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style=''>of</span> <span style=''>hydrocarbon</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resources</span> <span style=''>is</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complicated</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>process</span> <span style=''>where</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geological</span> <span style=''>geochemical</span> <span style=''>and</span> <span style=''>geophysical</span> <span style=''>factors</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>then</span> <span style=''>combined</span> <span style=''>together</span> <span style=''>It</span> <span style=''>is</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>how</span> <span style=''>to</span> <span style=''>design</span> <span style=''>the</span> <span style=''>seismic</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>survey</span> <span style=''>and</span> <span style=''>locate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style=''>wells</span> <span style=''>since</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorrect</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imprecise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>waste</span> <span style=''>of</span> <span style=''>time</span> <span style=''>and</span> <span style=''>money</span> <span style=''>during</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operation</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>this</span> <span style=''>study</span> <span style=''>is</span> <span style=''>to</span> <span style=''>locate</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>oil</span> <span style=''>and</span> <span style=''>gas</span> <span style=''>field</span> <span style=''>in</span> <span style=''>1</span> <span style=''>250000</span> <span style=''>sheet</span> <span style=''>of</span> <span style=''>Ahwaz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>20</span> <span style=''>oil</span> <span style=''>fields</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>both</span> <span style=''>time</span> <span style=''>and</span> <span style=''>costs</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>production</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>In</span> <span style=''>this</span> <span style=''>regard</span> <span style=''>17</span> <span style=''>maps</span> <span style=''>were</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>using</span> <span style=''>GIS</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Phylogenetic</span> <span style=''>Indian</span> <span style=''>Buffet</span> <span style=''>Process</span> <span style=''>A</span> <span style=''>Non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exchangeable</span> <span style='background-color:rgba(255, 0, 0, 0.7518248175182483);'>Nonparametric</span> <span style=''>Prior</span> <span style=''>for</span> <span style=''>Latent</span> <span style=''>Features</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.7518248175182483);'>Nonparametric</span> <span style=''>Bayesian</span> <span style=''>models</span> <span style=''>are</span> <span style=''>often</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style=''>objects</span> <span style=''>being</span> <span style=''>modeled</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exchangeable</span> <span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>in</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>(eg</span> <span style=''>bag</span> <span style=''>of</span> <span style=''>words</span> <span style=''>models</span> <span style=''>for</span> <span style=''>documents)</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>exchangeability</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sometimes</span> <span style=''>assumed</span> <span style=''>simply</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>reasons</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exchangeable</span> <span style=''>models</span> <span style=''>might</span> <span style=''>be</span> <span style=''>a</span> <span style=''>better</span> <span style=''>choice</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>based</span> <span style=''>on</span> <span style=''>subject</span> <span style=''>matter</span> <span style=''>Drawing</span> <span style=''>on</span> <span style=''>ideas</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3580246913580247);'>graphical</span> <span style=''>models</span> <span style=''>and</span> <span style=''>phylogenetics</span> <span style=''>we</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exchangeable</span> <span style=''>prior</span> <span style=''>for</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.7518248175182483);'>nonparametric</span> <span style=''>latent</span> <span style=''>feature</span> <span style=''>models</span> <span style=''>that</span> <span style=''>is</span> <span style=''>nearly</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style=''>as</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exchangeable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterpart</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>the</span> <span style=''>general</span> <span style=''>setting</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>de ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Modularity</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>for</span> <span style=''>Network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Trajectories</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>moving</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>road</span> <span style=''>network</span> <span style=''>The</span> <span style=''>approach</span> <span style=''>builds</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>graph</span> <span style=''>based</span> <span style=''>on</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>then</span> <span style=''>uses</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modularity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>hiearchical</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>to</span> <span style=''>regroup</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>with</span> <span style=''>similar</span> <span style=''>profiles</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>study</span> <span style=''>shows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>superiority</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>over</span> <span style=''>classic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>gives</span> <span style=''>a</span> <span style=''>brief</span> <span style=''>insight</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>results</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13211600429645542)
# 	segmentation (0.07017543859649122)
# 	knowledge (0.1310418904403867)
# 	architecture (0.08485499462943072)
# 	information (0.24060150375939848)
# 	representation (0.13390619405657)
# 	detection (0.12244897959183673)
# 	different (0.2699606158252775)
# 	convolutional (0.1385606874328679)
# 	recognition (0.1439312567132116)
#
# Some Statistics words are:
# 	stochastic (0.12954658694569007)
# 	statistical (0.14299950174389636)
# 	algorithm (0.39212755356253115)
# 	theoretical (0.15246636771300448)
# 	distribution (0.1684105630293971)
# 	estimation (0.16791230692575984)
# 	variables (0.1425012456402591)
# 	regression (0.16890881913303438)
# 	inference (0.20179372197309417)
# 	dimensional (0.19730941704035873)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d44ee69a-9008-4f60-bdd0-de9ebed1a209" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d44ee69a-9008-4f60-bdd0-de9ebed1a209")) {                    Plotly.newPlot(                        "d44ee69a-9008-4f60-bdd0-de9ebed1a209",                        [{"x":["minimally","particularly","assumptions","improving","personalizing","irrespective","experiments","documents","preferences","sufficient","judgments","reasonable","introduce","inexpensive","plentiful","probability","presentation","interactive","unaffected","collecting","presented","guaranteed","randomization","relevance","guarantees","intractable","computationally","regression","continuous","tractable","generalized","effectiveness","processing","synthetic","procedures","algorithms","optimization","measurement","approximation","constrained","relaxation","functions","established","otherwise","technique","combinatorial","selection","experiment","numerical","composition","distinguished","algorithm","characterize","constraint","dependencies","concentration","covariance","efficient","development","distribution","scoresearch","equivalence","conjecture","equivalent","transitivity","extension","particular","compromises","undirected","graphical","satisfies","interpretation","criterion","andersson","properties","marginalizing","faithfulness","unfortunately","varieties","quantities","nonlinear","situations","inventory","interaction","marketing","decreases","parameters","management","unobserved","motivated","variables","estimation","distributions","dimensional","discrepancies","expectation","assumption","consequence","maximization","annealing","components","consistently","promising","demonstrate","categorical","benchmarks","attributes","clustering","generating","representation","parameter","typically","probabilistic","structure","semantics","accompanying","conditions","inference","respected","attractive","completeness","therefore","techniques","describes","perceptron","piecewise","perceptrons","multilayer","performance","similarity","interpolation","annotation","supervised","empirical","weighting","dependency","influence","attachment","combination","sentences","adposition","significantly","comparing","subsequently","principal","correlated","multiplication","analytical","simultaneously","coherence","structured","normalized","different","remarkably","iterative","structures","unstructured","resemblance","recovered","component","challenging","automatic","convolutional","traditionally","microscope","incorporating","histology","requirement","pathologists","classification","metastases","framework","misdiagnosis","significant","predictions","computing","metastatic","diagnostic","indicators","surpassed","strategies","resolutions","prefetching","effectively","existence","detection","extensive","diagnosis","computerized","benchmark","expanding","metastasis","localization","asynchronous","leveraging","challenge","reconstructing","alleviates","classical","sensitivity","experimental","objective","establish","minimization","evaluation","furthermore","generated","expensive","evaluations","approximations","available","information","relatively","correspondingly","especially","developing","procedure","performed","surrogate","corresponding","calculation","multivariate","dimensionality","hypercube","effective","approaches","structural","computational","inferring","determinantal","challenges","constructs","statistical","applicability","extremely","optimizing","processes","performing","outperforms","iterations","validations","measuring","statistically","discrepancy","theoretically","essential","hypothesis","applications","specifically","important","designing","estimator","statistics","interpretable","adv ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	scoresearch
# 	andersson
# 	faithfulness
# 	governing
# 	gracefully
# 	quadrature
# 	parametrisation
# 	marginalize
# 	periodicity
# 	chemometrics
# 	convexification
# 	contractive
# 	hermitian
# 	extrapolation
# 	decomposability
# 	linearities
# 	misclassify
# 	factorial
# 	hypernetworks
# 	subroutines
# Some words which never appear in Statistics papers:
# 	minimally
# 	personalizing
# 	unaffected
# 	attachment
# 	adposition
# 	histology
# 	metastases
# 	misdiagnosis
# 	metastatic
# 	surpassed
# 	prefetching
# 	computerized
# 	constitutional
# 	plagiarism
# 	localizing
# 	occlusions
# 	quaternion
# 	parallelizing
# 	registrations
# 	ultrasound

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077207126811706e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333

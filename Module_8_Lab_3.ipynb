# %% [markdown]
# <a href="https://colab.research.google.com/github/NandikollaSatyaSuryakiran/FMML_LABS-AND-ASSIGNMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-01 07:30:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   149MB/s    in 0.5s
#
# 2024-04-01 07:30:09 (149 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26177  1609.01648v1  A spoof attack, a subset of presentation attac...    cs
# 9028   1801.09851v1  Motivation: Biomedical named entity recognitio...    cs
# 21804  1604.04054v1  We consider a statistical inverse learning pro...  stat
# 10535   1207.3438v1  Non-negative matrix factorization (NMF) approx...  stat
# 26666  1611.05927v1  This paper introduces an extension of the back...    cs
# ...             ...                                                ...   ...
# 10565   1303.5145v4  We consider the problem of estimating high-dim...  stat
# 40491   1204.0136v1  In several online prediction problems of recen...    cs
# 13417   1209.2717v1  Two metaheuristic algorithms namely Artificial...    cs
# 4748    1007.2449v1  Causality is a non-obvious concept that is oft...    cs
# 35017  1508.01168v1  In this paper, we investigate the downlink mul...    cs
#
#                                                    title  year  \
# 26177  Review of the Fingerprint Liveness Detection (...  2016
# 9028   Cross-type Biomedical Named Entity Recognition...  2018
# 21804  Optimal Rates For Regularization Of Statistica...  2016
# 10535  MahNMF: Manhattan Non-negative Matrix Factoriz...  2012
# 26666  Generalized BackPropagation, Étude De Cas: Ort...  2016
# ...                                                  ...   ...
# 10565  Node-Based Learning of Multiple Gaussian Graph...  2013
# 40491  Near-Optimal Algorithms for Online Matrix Pred...  2012
# 13417  Comparison Study for Clonal Selection Algorith...  2012
# 4748   A Brief Introduction to Temporality and Causality  2010
# 35017  Particle Swarm Optimization for Weighted Sum R...  2015
#
#                                                 keywords
# 26177  [presentation, artificial, biometric, circumve...
# 9028   [motivation, biomedical, recognition, fundamen...
# 21804  [statistical, superposed, distribution, simult...
# 10535  [factorization, approximates, extensions, dive...
# 26666  [introduces, extension, backpropagation, algor...
# ...                                                  ...
# 10565  [estimating, dimensional, graphical, correspon...
# 40491  [prediction, comparison, comparison, represent...
# 13417  [metaheuristic, algorithms, artificial, algori...
# 4748   [causality, considered, temporality, approache...
# 35017  [investigate, multipleoutput, broadcast, trans...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26177    [presentation, artificial, biometric, circumve...
# 9028     [motivation, biomedical, recognition, fundamen...
# 21804    [statistical, superposed, distribution, simult...
# 10535    [factorization, approximates, extensions, dive...
# 26666    [introduces, extension, backpropagation, algor...
#                                ...
# 29101    [convolutional, denoising, exponential, activa...
# 8667     [generative, represent, represent, seenunseen,...
# 28426    [hierarchical, overlapping, detections, employ...
# 10792    [introduce, recognition, background, estimatin...
# 28148    [understanding, different, information, includ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8797 words.
# Out of those 4598 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac298466-56a4-49ac-81a9-93676c57fee8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac298466-56a4-49ac-81a9-93676c57fee8")) {                    Plotly.newPlot(                        "ac298466-56a4-49ac-81a9-93676c57fee8",                        [{"x":["circumvent","fingerprint","submissions","continuous","quantities","biometric","standardized","algorithms","participants","information","capabilities","institutions","industrial","authentication","fingerprints","noticeable","demonstrates","incorporate","competition","artificial","presentation","themselves","additional","detection","determine","principle","authentic","competitors","distinguishes","competitions","motivation","framework","fundamental","handcrafted","recognition","approaches","generation","parameters","character","performance","linguistic","biomedical","different","substantial","capturing","collectively","available","intensive","difficult","benchmark","characteristics","outperforms","literature","scientists","opportunities","experiments","specifically","knowledge","superposed","regularity","distribution","convergence","conditions","optimality","regularization","appropriate","observations","completes","statistical","condition","simultaneously","dependency","practical","extensions","minimizes","laplacian","recursively","contaminated","manhattan","particular","constrained","nesterovs","approximating","proportional","decompositions","efficient","objective","developing","divergence","factorization","approximation","smoothing","applications","contribution","iteration","estimates","symmetric","effectively","inversely","iteratively","functions","regularized","parameter","optimization","euclidean","approximates","demonstrate","extension","dimensionality","orthogonal","riemannian","algorithm","backpropagation","generalized","extraction","reduction","orthogonality","structures","unsupervised","equipping","introduces","development","definiteness","classification","techniques","manifolds","introducing","iterations","injection","transition","procedure","challenging","stochastic","theoretical","guarantee","retaining","progressively","empirical","initialization","important","solutions","challenge","guarantees","nonconvex","continuation","guaranteed","requirement","principal","partition","performances","experimental","similarity","dictionary","representation","synthetic","decomposition","structure","preservation","suppressing","performed","hierarchical","generalizable","generalization","combinatorial","complexity","importantly","generalizes","landscape","environments","satisfactory","reinforcement","heuristic","following","organization","configuration","transparent","strategies","inspection","simplified","exploited","construct","variations","traditional","biologically","facilitate","limitation","dimensional","motivated","typically","delineated","reproducing","simulations","sequentially","excellent","prediction","optimizing","especially","presented","sequential","estimation"],"y":[5,9,3,108,17,14,9,572,20,724,47,7,15,12,7,4,57,80,25,141,14,21,116,314,63,66,3,7,6,4,26,520,93,15,368,446,153,250,58,903,62,18,727,41,42,7,295,30,158,204,93,262,132,12,16,625,174,356,0,7,211,111,134,34,80,74,73,1,153,51,101,42,138,32,15,19,17,7,1,281,55,2,19,10,7,396,151,69,22,36,132,19,464,84,37,56,19,116,1,29,204,35,112,290,28,11,553,72,66,21,13,842,21,74,139,93,3,122,148,3,83,118,3,460,358,16,51,24,3,26,102,290,120,170,30,10,12,139,31,357,130,135,52,11,3,31,21,36,32,50,367,145,47,375,125,64,371,11,2,146,117,6,113,31,220,27,32,14,79,25,100,51,86,26,25,8,90,11,23,26,91,77,159,14,44,33,182,57,112,1,10,51,23,26,215,50,122,202,78,216],"type":"bar"},{"x":["circumvent","fingerprint","submissions","co ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4598,), (4598, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7983333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Language</span> <span style=''>of</span> <span style=''>Search</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concerned</span> <span style=''>with</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>exhaustive</span> <span style=''>search</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style='background-color:rgba(0, 255, 0, 0.38791423001949327);'>knowledge</span> <span style=''>bases</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>each</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>defines</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5517241379310345);'>generates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>trace</span> <span style=''>of</span> <span style=''>a</span> <span style=''>search</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>combinational</span> <span style=''>circuit</span> <span style=''>and</span> <span style=''>a</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>then</span> <span style=''>defines</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.40476190476190477);'>consisting</span> <span style=''>of</span> <span style=''>circuits</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.30526315789473685);'>generated</span> <span style=''>across</span> <span style=''>all</span> <span style=''>possible</span> <span style=''>executions</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>several</span> <span style=''>versions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>exhaustive</span> <span style=''>DPLL</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.32000000000000006);'>correspond</span> <span style=''>to</span> <span style=''>such</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.875);'>languages</span> <span style=''>as</span> <span style=''>FBDD</span> <span style=''>OBDD</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precisely</span> <span style=''>defined</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>d</span> <span style=''>DNNF</span> <span style=''>By</span> <span style=''>thus</span> <span style=''>mapping</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style='background-color:rgba(0, 25 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Wild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bootstrap</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Degenerate</span> <span style=''>Kernel</span> <span style=''>Tests</span> <br/><br/><span style=''>A</span> <span style=''>wild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>tests</span> <span style=''>based</span> <span style=''>on</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>method</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>provably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>tests</span> <span style=''>that</span> <span style=''>apply</span> <span style=''>to</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>for</span> <span style=''>which</span> <span style=''>the</span> <span style=''>naive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>permutation</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>fails</span> <span style=''>It</span> <span style=''>applies</span> <span style=''>to</span> <span style=''>a</span> <span style=''>large</span> <span style=''>group</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>tests</span> <span style=''>based</span> <span style=''>on</span> <span style=''>V</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>degenerate</span> <span style=''>under</span> <span style=''>the</span> <span style=''>null</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>and</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>degenerate</span> <span style=''>elsewhere</span> <span style=''>To</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>two</span> <span style=''>sample</span> <span style=''>test</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instantaneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>test</span> <span style=''>and</span> <span style=''>a</span> <span style=''>multiple</span> <span style=''>lag</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>test</span> <span style=''>for</span> <span style=''>time</span> <span style=''>series</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>the</span> <span style=''>wild</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>gives</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>examples</span> <span style=''>on</span> <span style=''>audio</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.4181818181818182);'>Numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sensitivity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficiency</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Treatment</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>Epistemic</span> <span style=''>and</span> <span style=''>Aleatory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uncertainty</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>treatment</span> <span style=''>of</span> <span style=''>both</span> <span style=''>aleatory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>epistemic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>by</span> <span style=''>recent</span> <span style=''>methods</span> <span style=''>often</span> <span style=''>requires</span> <span style=''>an</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>effort</span> <span style=''>In</span> <span style=''>this</span> <span style=''>abstract</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.4181818181818182);'>numerical</span> <span style=''>sampling</span> <span style=''>method</span> <span style=''>allowing</span> <span style=''>to</span> <span style=''>lighten</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>burden</span> <span style=''>of</span> <span style=''>treating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style=''>so</span> <span style=''>called</span> <span style=''>fuzzy</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3705357142857142);'>variables</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Static</span> <span style=''>Gesture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recognition</span> <span style=''>using</span> <span style=''>Leap</span> <span style=''>Motion</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>report</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style=''>bartender</span> <span style=''>system</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>making</span> <span style=''>orders</span> <span style=''>in</span> <span style=''>a</span> <span style=''>bar</span> <span style=''>using</span> <span style=''>hand</span> <span style=''>gestures</span> <span style=''>The</span> <span style=''>gesture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>using</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>where</span> <span style=''>the</span> <span style=''>model</span> <span style=''>was</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>gestures</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>data</span> <span style=''>The</span> <span style=''>final</span> <span style=''>model</span> <span style=''>used</span> <span style=''>in</span> <span style=''>the</span> <span style=''>system</span> <span style=''>reached</span> <span style=''>an</span> <span style=''>average</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>95</span> <span style=''>The</span> <span style=''>system</span> <span style=''>raised</span> <span style=''>ethical</span> <span style=''>concerns</span> <span style=''>both</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>user</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>and</span> <span style=''>having</span> <span style=''>such</span> <span style=''>a</span> <span style=''>system</span> <span style=''>in</span> <span style=''>a</span> <span style=''>real</span> <span style=''>world</span> <span style=''>scenario</span> <span style=''>but</span> <span style=''>it</span> <span style=''>could</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initially</span> <span style=''>work</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complement</span> <span style=''>to</span> <span style=''>a</span> <span style=''>real</span> <span style=''>bartender</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06580829756795423)
# 	knowledge (0.12732474964234622)
# 	challenging (0.10371959942775394)
# 	detection (0.1123032904148784)
# 	information (0.25894134477825465)
# 	representation (0.13412017167381973)
# 	different (0.2600143061516452)
# 	architecture (0.09585121602288985)
# 	convolutional (0.13125894134477825)
# 	recognition (0.13161659513590845)
#
# Some Statistics words are:
# 	algorithm (0.3872255489021956)
# 	theoretical (0.14870259481037923)
# 	statistical (0.14570858283433133)
# 	estimation (0.1686626746506986)
# 	stochastic (0.13572854291417166)
# 	variables (0.1531936127744511)
# 	distribution (0.18562874251497005)
# 	inference (0.20758483033932135)
# 	dimensional (0.19560878243512975)
# 	regression (0.18113772455089822)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c9af65a4-1664-4adb-8dc8-f60d64ab9291" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9af65a4-1664-4adb-8dc8-f60d64ab9291")) {                    Plotly.newPlot(                        "c9af65a4-1664-4adb-8dc8-f60d64ab9291",                        [{"x":["circumvent","fingerprint","submissions","continuous","quantities","biometric","standardized","algorithms","participants","information","capabilities","institutions","industrial","authentication","fingerprints","noticeable","demonstrates","incorporate","competition","artificial","presentation","themselves","additional","detection","determine","principle","authentic","competitors","distinguishes","competitions","motivation","framework","fundamental","handcrafted","recognition","approaches","generation","parameters","character","performance","linguistic","biomedical","different","substantial","capturing","collectively","available","intensive","difficult","benchmark","characteristics","outperforms","literature","scientists","opportunities","experiments","specifically","knowledge","superposed","regularity","distribution","convergence","conditions","optimality","regularization","appropriate","observations","completes","statistical","condition","simultaneously","dependency","practical","extensions","minimizes","laplacian","recursively","contaminated","manhattan","particular","constrained","nesterovs","approximating","proportional","decompositions","efficient","objective","developing","divergence","factorization","approximation","smoothing","applications","contribution","iteration","estimates","symmetric","effectively","inversely","iteratively","functions","regularized","parameter","optimization","euclidean","approximates","demonstrate","extension","dimensionality","orthogonal","riemannian","algorithm","backpropagation","generalized","extraction","reduction","orthogonality","structures","unsupervised","equipping","introduces","development","definiteness","classification","techniques","manifolds","introducing","iterations","injection","transition","procedure","challenging","stochastic","theoretical","guarantee","retaining","progressively","empirical","initialization","important","solutions","challenge","guarantees","nonconvex","continuation","guaranteed","requirement","principal","partition","performances","experimental","similarity","dictionary","representation","synthetic","decomposition","structure","preservation","suppressing","performed","hierarchical","generalizable","generalization","combinatorial","complexity","importantly","generalizes","landscape","environments","satisfactory","reinforcement","heuristic","following","organization","configuration","transparent","strategies","inspection","simplified","exploited","construct","variations","traditional","biologically","facilitate","limitation","dimensional","motivated","typically","delineated","reproducing","simulations","sequentially","excellent","prediction","optimizing","especially","presented","sequential","estimation","developed","nonlinear","technique","confirmed","estimated","selecting","intuitions","challenges","crowdworkers","unintuitive","comparisons","exploiting","effective","collection","collecting","supervised","formulate","instances","practices","individual","regression","harnessed","constraints","scenarios","considerably","demonstrating","aggregated","lightweight","crowdsourcing","complement","relations","robustness","automatically","efficiently","nonnegative","hyperspectral","polynomial","separable","meaningful","mathematics","illustrate","processing","contribute","particularly","translate","interesting","technologies","organizational","traceability","pharmaceutical","ingredients","representations","authe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	superposed
# 	reparameterization
# 	tightness
# 	covariances
# 	preceding
# 	increments
# 	correntropy
# 	depression
# 	emphdirectly
# 	procrustes
# 	inverting
# 	parametrisation
# 	uncollapsed
# 	debiasing
# 	nonparanormal
# 	invertibility
# 	intracellular
# 	amortization
# 	governing
# 	readmission
# Some words which never appear in Statistics papers:
# 	authentic
# 	competitions
# 	equipping
# 	suppressing
# 	organizational
# 	traceability
# 	authenticity
# 	contracts
# 	proactive
# 	ethnicity
# 	accountability
# 	repairing
# 	initiatives
# 	overestimation
# 	pheromone
# 	deposition
# 	arranging
# 	displacements
# 	explodingvanishing
# 	cooperate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0714417347502915e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
